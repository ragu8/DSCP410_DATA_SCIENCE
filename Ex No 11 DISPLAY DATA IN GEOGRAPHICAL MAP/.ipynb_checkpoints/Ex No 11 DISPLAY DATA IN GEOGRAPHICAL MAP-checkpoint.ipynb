# %% [markdown]
# ##### AIM:
# To use the GeoPandas package to plot data in geographical map.

# %%
# !pip install --upgrade geopandas
# Out:
# Requirement already satisfied: geopandas in c:\anaconda\lib\site-packages (0.12.2)
# Requirement already satisfied: packaging in c:\anaconda\lib\site-packages (from geopandas) (21.3)
# Requirement already satisfied: shapely>=1.7 in c:\anaconda\lib\site-packages (from geopandas) (2.0.0)
# Requirement already satisfied: pyproj>=2.6.1.post1 in c:\anaconda\lib\site-packages (from geopandas) (3.4.1)
# Requirement already satisfied: pandas>=1.0.0 in c:\anaconda\lib\site-packages (from geopandas) (1.4.4)
# Requirement already satisfied: fiona>=1.8 in c:\anaconda\lib\site-packages (from geopandas) (1.8.22)
# Requirement already satisfied: munch in c:\anaconda\lib\site-packages (from fiona>=1.8->geopandas) (2.5.0)
# Requirement already satisfied: click>=4.0 in c:\anaconda\lib\site-packages (from fiona>=1.8->geopandas) (8.0.4)
# Requirement already satisfied: attrs>=17 in c:\anaconda\lib\site-packages (from fiona>=1.8->geopandas) (21.4.0)
# Requirement already satisfied: certifi in c:\anaconda\lib\site-packages (from fiona>=1.8->geopandas) (2022.9.14)
# Requirement already satisfied: click-plugins>=1.0 in c:\anaconda\lib\site-packages (from fiona>=1.8->geopandas) (1.1.1)
# Requirement already satisfied: six>=1.7 in c:\anaconda\lib\site-packages (from fiona>=1.8->geopandas) (1.16.0)
# Requirement already satisfied: cligj>=0.5 in c:\anaconda\lib\site-packages (from fiona>=1.8->geopandas) (0.7.2)
# Requirement already satisfied: setuptools in c:\anaconda\lib\site-packages (from fiona>=1.8->geopandas) (63.4.1)
# Requirement already satisfied: pytz>=2020.1 in c:\anaconda\lib\site-packages (from pandas>=1.0.0->geopandas) (2022.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\anaconda\lib\site-packages (from pandas>=1.0.0->geopandas) (2.8.2)
# Requirement already satisfied: numpy>=1.18.5 in c:\anaconda\lib\site-packages (from pandas>=1.0.0->geopandas) (1.21.5)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\anaconda\lib\site-packages (from packaging->geopandas) (3.0.9)
# Requirement already satisfied: colorama in c:\anaconda\lib\site-packages (from click>=4.0->fiona>=1.8->geopandas) (0.4.5)

# %%
import geopandas
import matplotlib.pyplot as plt

# %%
world = geopandas.read_file(geopandas.datasets.get_path('naturalearth_lowres'))
world = world[(world.name=="India")]

# %%
fig, ax = plt.subplots(1, 1)
world.plot(column='gdp_md_est', ax=ax, legend=True, cmap='BuGn')
# Out:
# <AxesSubplot:>
