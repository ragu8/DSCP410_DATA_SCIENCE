# %% [markdown]
# ##### AIM:
# To perform data wrangling using Pandas.

# %%
import pandas as pd
import numpy as np

# %%
# Function to get the mean and median values of MYCT, MMIN, MMAX, CACH, CHMIN, CHMAX, and PRP for each vendor name
def fn_get_model_myct(df):
    # Display the original data frame
    display(df)
    # Calculate mean values for MYCT, MMIN, MMAX, CACH, CHMIN, CHMAX, and PRP for each vendor name
    df_mean = pd.pivot_table(df, values=["MYCT", "MMIN", "MMAX", "CACH", "CHMIN","CHMAX", "PRP"], columns="vendor name", aggfunc = np.mean)
    display(df_mean)
    # Calculate median values for MYCT, MMIN, MMAX, CACH, CHMIN, CHMAX, and PRP for each vendor name
    df_median = pd.pivot_table(df, values=["MYCT", "MMIN", "MMAX", "CACH", "CHMIN","CHMAX", "PRP"], columns="vendor name", aggfunc = np.mean)
    # Store mean values of MYCT for each vendor name in a new data frame
    df_myct_mean = pd.DataFrame({"vendor name" : list(df_mean.columns),"Mean MYCT":df_mean.values.tolist()[5]})
    # Reshape the original data frame to keep only vendor name and model name columns
    df_melt_models = pd.melt(df, id_vars =["vendor name"], value_vars =["Model Name"])
    # Reshape the data frame storing mean MYCT values to keep only vendor name and mean MYCT columns
    df_melt_myct_mean = pd.melt(df_myct_mean, id_vars =["vendor name"], value_vars=["Mean MYCT"])
    # Concatenate the two melted data frames
    data_model_myct = pd.concat([df_melt_models, df_melt_myct_mean], ignore_index=True)
    # Return the concatenated data frame
    return data_model_myct

# %%
if __name__ == "__main__":
    # Read the csv file and store it as a pandas data frame
    data_frame_ip = pd.read_csv("machine.data", index_col=None, header=None,
    names=["vendor name", "Model Name", "MYCT", "MMIN", "MMAX", "CACH", "CHMIN","CHMAX", "PRP", "ERP"])
    # Call the function to get the mean and median values of MYCT, MMIN, MMAX, CACH, CHMIN, CHMAX, and PRP for each vendor name
    data_model_myct = fn_get_model_myct(data_frame_ip)
    # Print the final data frame
    print(data_model_myct)
# Out:
#     vendor name     Model Name  MYCT  MMIN   MMAX  CACH  CHMIN  CHMAX  PRP  \
# 0       adviser          32/60   125   256   6000   256     16    128  198
# 1        amdahl         470v/7    29  8000  32000    32      8     32  269
# 2        amdahl        470v/7a    29  8000  32000    32      8     32  220
# 3        amdahl        470v/7b    29  8000  32000    32      8     32  172
# 4        amdahl        470v/7c    29  8000  16000    32      8     16  132
# ..          ...            ...   ...   ...    ...   ...    ...    ...  ...
# 204      sperry           80/8   124  1000   8000     0      1      8   42
# 205      sperry  90/80-model-3    98  1000   8000    32      2      8   46
# 206      sratus             32   125  2000   8000     0      2     14   52
# 207        wang         vs-100   480   512   8000    32      0      0   67
# 208        wang          vs-90   480  1000   4000     0      0      0   45
#
#      ERP
# 0    199
# 1    253
# 2    253
# 3    253
# 4    132
# ..   ...
# 204   37
# 205   50
# 206   41
# 207   47
# 208   25
#
# [209 rows x 10 columns]
# vendor name  adviser        amdahl  apollo     basf     bti  burroughs  \
# CACH           256.0     56.888889     2.0     65.0     0.0     18.750
# CHMAX          128.0     33.777778     4.0      8.0    18.0     38.375
# CHMIN           16.0     13.333333     1.0      1.0     2.5      5.750
# MMAX          6000.0  37333.333333  3250.0  12000.0  8032.0   4862.500
# MMIN           256.0  13333.333333   756.0   3000.0   288.0   2129.500
# MYCT           125.0     26.000000   400.0     55.0   275.0    137.750
# PRP            198.0    416.333333    39.0    115.0    22.5     49.750
#
# vendor name        c.r.d   cambex          cdc          dec  ...  microdata  \
# CACH            2.666667      8.0    45.111111     6.333333  ...        0.0
# CHMAX           5.833333      5.4    17.555556     6.500000  ...      128.0
# CHMIN           1.000000      3.0     8.333333     1.666667  ...        8.0
# MMAX         4500.000000  12000.0  9126.666667  6918.666667  ...     4000.0
# MMIN          320.000000   1600.0  2426.666667   756.000000  ...      512.0
# MYCT          320.000000     50.0    46.666667   401.000000  ...      150.0
# PRP            42.666667     42.8   130.111111    47.333333  ...       30.0
#
# vendor name           nas          ncr      nixdorf  perkin-elmer   prime  \
# CACH            55.052632    32.000000    21.333333      0.333333    12.0
# CHMAX           13.473684    12.923077     3.666667      7.333333    10.8
# CHMIN            5.684211     4.923077     1.000000      2.000000     1.4
# MMAX         17894.736842  9923.076923  4666.666667   8000.000000  5200.0
# MMIN          5368.421053  3615.384615  1333.333333    674.666667  1004.8
# MYCT            64.421053    55.538462   200.000000    250.000000   160.0
# PRP            176.894737    63.307692    32.000000     41.666667    53.8
#
# vendor name       siemens        sperry  sratus    wang
# CACH            34.666667     44.923077     0.0    16.0
# CHMAX           13.833333     53.384615    14.0     0.0
# CHMIN            7.250000     13.230769     2.0     0.0
# MMAX         13750.000000  22769.230769  8000.0  6000.0
# MMIN          4252.000000   2426.769231  2000.0   756.0
# MYCT            92.750000    101.384615   125.0   480.0
# PRP            121.833333    254.923077    52.0    56.0
#
# [7 rows x 30 columns]
#     vendor name    variable       value
# 0       adviser  Model Name       32/60
# 1        amdahl  Model Name      470v/7
# 2        amdahl  Model Name     470v/7a
# 3        amdahl  Model Name     470v/7b
# 4        amdahl  Model Name     470v/7c
# ..          ...         ...         ...
# 234       prime   Mean MYCT       160.0
# 235     siemens   Mean MYCT       92.75
# 236      sperry   Mean MYCT  101.384615
# 237      sratus   Mean MYCT       125.0
# 238        wang   Mean MYCT       480.0
#
# [239 rows x 3 columns]
